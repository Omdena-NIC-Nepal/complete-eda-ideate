# %% [markdown]
# # Climate Data Exploratory Data Analysis
#
# ## Introduction
# This notebook contains an exploratory data analysis of climate data from 1900 to 2023. The dataset includes global temperatures, CO2 concentration, sea level rise, and Arctic ice area.
#
# Your task is to perform a comprehensive EDA following the requirements in the README.md file.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot styling
# plt.style.use('seaborn-whitegrid')
sns.set_palette('viridis')
# %matplotlib inline

# %% [markdown]
# ## 1. Data Preparation
#
# Load the climate data and perform necessary cleaning and aggregation.

# %%
# Load the dataset
df = pd.read_csv('data/Climate_Change_Indicators.csv') # Place the correct path to the file you are reading here (Make sure to load using the relative path)

# Display the first few rows of the dataset
# df.head(10)
df[0:10]
# Out:
#    Year  Global Average Temperature (°C)  CO2 Concentration (ppm)  \
# 0  1948                            13.17                   397.04
# 1  1996                            13.10                   313.17
# 2  2015                            14.67                   311.95
# 3  1966                            14.79                   304.25
# 4  1992                            13.15                   354.52
# 5  1907                            13.67                   288.50
# 6  1999                            15.63                   350.70
# 7  1977                            13.41                   333.02
# 8  2013                            14.21                   358.54
# 9  1904                            15.51                   404.95
#
#    Sea Level Rise (mm)  Arctic Ice Area (million km²)
# 0               116.25                           5.97
# 1               277.92                           9.66
# 2               290.32                           8.40
# ...

# %%
# Check for missing values and basic information about the dataset
print("Dataset Information:")
print(df.info())
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048576 entries, 0 to 1048575
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   Year                             1048576 non-null  int64
#  1   Global Average Temperature (°C)  1048576 non-null  float64
#  2   CO2 Concentration (ppm)          1048576 non-null  float64
#  3   Sea Level Rise (mm)              1048576 non-null  float64
#  4   Arctic Ice Area (million km²)    1048576 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 40.0 MB
# None
#
# Missing Values:
# Year                               0
# Global Average Temperature (°C)    0
# CO2 Concentration (ppm)            0
# Sea Level Rise (mm)                0
# Arctic Ice Area (million km²)      0
# dtype: int64

# %%
# TODO: Aggregate data by year to create a 124-year time series
# Your code here
aggregate_data_by_year = df.groupby("Year").mean().sort_index()
aggregate_data_by_year
# Out:
#       Global Average Temperature (°C)  CO2 Concentration (ppm)  \
# Year
# 1900                        14.506663               350.373405
# 1901                        14.485343               349.757140
# 1902                        14.476262               349.299686
# 1903                        14.492360               349.644375
# 1904                        14.494241               349.537032
# ...                               ...                      ...
# 2019                        14.500105               348.642249
# 2020                        14.496937               350.021731
# 2021                        14.501424               350.150302
# 2022                        14.495233               350.493023
# 2023                        14.474559               351.003294
#
#       Sea Level Rise (mm)  Arctic Ice Area (million km²)
# Year
# 1900           150.408288                       8.978659
# 1901           150.548828                       8.947272
# ...

# %% [markdown]
# ### Descriptive statistics

# %%
round(df.drop(columns=['Year']).describe(), 2)
# Out:
#        Global Average Temperature (°C)  CO2 Concentration (ppm)  \
# count                       1048576.00               1048576.00
# mean                             14.50                   350.03
# std                               0.87                    40.42
# min                              13.00                   280.00
# 25%                              13.75                   314.99
# 50%                              14.50                   350.07
# 75%                              15.25                   385.02
# max                              16.00                   420.00
#
#        Sea Level Rise (mm)  Arctic Ice Area (million km²)
# count           1048576.00                     1048576.00
# mean                149.99                           9.00
# std                  86.58                           3.46
# min                   0.00                           3.00
# 25%                  74.97                           6.00
# ...

# %% [markdown]
# ## 2. Univariate Analysis
#
# Analyze each climate variable independently.

# %%
# TODO: Perform univariate analysis for each climate variable
# Include descriptive statistics and appropriate visualizations

# %% [markdown]
# ### Creating Histogram

# %%
# Creating Histogram of  Global Average Temparature in (C)
plt.figure(figsize=(10, 4))
sns.histplot(aggregate_data_by_year['Global Average Temperature (°C)'], bins=20, kde=True)
plt.title("Distribution of Global Temperature")
plt.xlabel("Global Temperature")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Creating Histogram of CO2 Concentration

plt.figure(figsize=(10, 4))
sns.histplot(aggregate_data_by_year['CO2 Concentration (ppm)'], bins=20, kde=True)
plt.title("Distribution of CO2 Concentration")
plt.xlabel("CO2 Concentration")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Creating Histogram of Sea Level Rise
plt.figure(figsize=(10, 4))
sns.histplot(aggregate_data_by_year['Sea Level Rise (mm)'], bins=20, kde=True)
plt.title("Distribution of Sea Level Rise")
plt.xlabel("Sea Level Rise")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Creating Histogram of Arctic Ice Area
plt.figure(figsize=(10, 4))
sns.histplot(aggregate_data_by_year['Arctic Ice Area (million km²)'], bins=20, kde=True)
plt.title("Distribution of Arctic Ice Area")
plt.xlabel("Arctic Ice Area")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Creating Box Plots

# %%
# Exclude the 'Year' column
climate_variables = df.drop(columns=['Year'])

# Create a 2x2 subplot layout
fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # 2 rows, 2 columns

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Loop through each variable and plot in a separate subplot
for i, column in enumerate(aggregate_data_by_year.columns):
    sns.boxplot(y=df[column], ax=axes[i])  # Plot boxplot
    axes[i].set_title(f"Box Plot of {column}")  # Set title

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ### Creating Time Series Plot

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Global Temperature (Top-Left)
sns.lineplot(x=df['Year'], y=df['Global Average Temperature (°C)'], marker='o', linestyle='-', ax=axes[0, 0])
axes[0, 0].set_title("Global Temperature Over Time")
axes[0, 0].set_xlabel("Year")
axes[0, 0].set_ylabel("Global Temperature (°C)")
axes[0, 0].grid(True)

# CO2 Concentration (Top-Right)
sns.lineplot(x=df['Year'], y=df['CO2 Concentration (ppm)'], marker='o', linestyle='-', ax=axes[0, 1])
axes[0, 1].set_title("CO2 Concentration Over Time")
axes[0, 1].set_xlabel("Year")
axes[0, 1].set_ylabel("CO2 Concentration (ppm)")
axes[0, 1].grid(True)

# Sea Level Rise (Bottom-Left)
sns.lineplot(x=df['Year'], y=df['Sea Level Rise (mm)'], marker='o', linestyle='-', ax=axes[1, 0])
axes[1, 0].set_title("Sea Level Rise Over Time")
axes[1, 0].set_xlabel("Year")
axes[1, 0].set_ylabel("Sea Level Rise (mm)")
axes[1, 0].grid(True)

# Arctic Ice Area (Bottom-Right)
sns.lineplot(x=df['Year'], y=df['Arctic Ice Area (million km²)'], marker='o', linestyle='-', ax=axes[1, 1])
axes[1, 1].set_title("Arctic Ice Area Over Time")
axes[1, 1].set_xlabel("Year")
axes[1, 1].set_ylabel("Arctic Ice Area (million km²)")
axes[1, 1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('climate_data_over_time.png', dpi=300)
# Show the figure
plt.show()

# %% [markdown]
# ## 3. Bivariate Analysis
#
# Explore relationships between pairs of climate variables.

# %%
# TODO: Perform bivariate analysis
# Include correlation analysis and appropriate visualizations
# Your code here
# # Exclude the 'Year' column from correlation matrix and pairplot
# df_without_year = df.drop(columns=['Year'])

# Correlation Matrix (Excluding 'Year')
correlation_matrix = aggregate_data_by_year.corr()
print("Correlation Matrix:\n", correlation_matrix)

# Heatmap for correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix of Climate Variable")
plt.show()
plt.show()
# Out:
# Correlation Matrix:
#                                   Global Average Temperature (°C)  \
# Global Average Temperature (°C)                         1.000000
# CO2 Concentration (ppm)                                -0.067980
# Sea Level Rise (mm)                                     0.003878
# Arctic Ice Area (million km²)                           0.047027
#
#                                  CO2 Concentration (ppm)  Sea Level Rise (mm)  \
# Global Average Temperature (°C)                -0.067980             0.003878
# CO2 Concentration (ppm)                         1.000000             0.098212
# Sea Level Rise (mm)                             0.098212             1.000000
# Arctic Ice Area (million km²)                   0.009986             0.129528
#
#                                  Arctic Ice Area (million km²)
# Global Average Temperature (°C)                       0.047027
# CO2 Concentration (ppm)                               0.009986
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(14, 12))

# Scatter plot for Global Average Temperature vs CO2 Concentration
sns.scatterplot(x=aggregate_data_by_year['Global Average Temperature (°C)'], 
                y=aggregate_data_by_year['CO2 Concentration (ppm)'], ax=axes[0, 0])
axes[0, 0].set_title("Global Temperature vs CO2 Concentration")
axes[0, 0].set_xlabel("Global Average Temperature (°C)")
axes[0, 0].set_ylabel("CO2 Concentration (ppm)")
axes[0, 0].grid(True)

# Scatter plot for Global Average Temperature vs Sea Level Rise
sns.scatterplot(x=aggregate_data_by_year['Global Average Temperature (°C)'], 
                y=aggregate_data_by_year['Sea Level Rise (mm)'], ax=axes[0, 1])
axes[0, 1].set_title("Global Temperature vs Sea Level Rise")
axes[0, 1].set_xlabel("Global Average Temperature (°C)")
axes[0, 1].set_ylabel("Sea Level Rise (mm)")
axes[0, 1].grid(True)

# Scatter plot for Global Average Temperature vs Arctic Ice Area
sns.scatterplot(x=aggregate_data_by_year['Global Average Temperature (°C)'], 
                y=aggregate_data_by_year['Arctic Ice Area (million km²)'], ax=axes[1, 0])
axes[1, 0].set_title("Global Temperature vs Arctic Ice Area")
axes[1, 0].set_xlabel("Global Average Temperature (°C)")
axes[1, 0].set_ylabel("Arctic Ice Area (million km²)")
axes[1, 0].grid(True)

# Scatter plot for CO2 Concentration vs Sea Level Rise
sns.scatterplot(x=aggregate_data_by_year['CO2 Concentration (ppm)'], 
                y=aggregate_data_by_year['Sea Level Rise (mm)'], ax=axes[1, 1])
axes[1, 1].set_title("CO2 Concentration vs Sea Level Rise")
axes[1, 1].set_xlabel("CO2 Concentration (ppm)")
axes[1, 1].set_ylabel("Sea Level Rise (mm)")
axes[1, 1].grid(True)

# Scatter plot for CO2 Concentration vs Arctic Ice Area
sns.scatterplot(x=aggregate_data_by_year['CO2 Concentration (ppm)'], 
                y=aggregate_data_by_year['Arctic Ice Area (million km²)'], ax=axes[2, 0])
axes[2, 0].set_title("CO2 Concentration vs Arctic Ice Area")
axes[2, 0].set_xlabel("CO2 Concentration (ppm)")
axes[2, 0].set_ylabel("Arctic Ice Area (million km²)")
axes[2, 0].grid(True)

# Scatter plot for Sea Level Rise vs Arctic Ice Area
sns.scatterplot(x=aggregate_data_by_year['Sea Level Rise (mm)'], 
                y=aggregate_data_by_year['Arctic Ice Area (million km²)'], ax=axes[2, 1])
axes[2, 1].set_title("Sea Level Rise vs Arctic Ice Area")
axes[2, 1].set_xlabel("Sea Level Rise (mm)")
axes[2, 1].set_ylabel("Arctic Ice Area (million km²)")
axes[2, 1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('climate_data_scatter_plot_over_time.png', dpi=300)
# Show the figure
plt.show()

# %% [markdown]
# ### Exploring Relationships Among Three Variables with 3D Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Create 3D plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the data
ax.scatter(aggregate_data_by_year['CO2 Concentration (ppm)'], 
           aggregate_data_by_year['Global Average Temperature (°C)'], 
           aggregate_data_by_year['Sea Level Rise (mm)'], 
           c=aggregate_data_by_year['Arctic Ice Area (million km²)'], cmap='coolwarm')

# Labels and title
ax.set_xlabel("CO2 Concentration (ppm)")
ax.set_ylabel("Global Temperature (°C)")
ax.set_zlabel("Sea Level Rise (mm)")
ax.set_title("3D Plot: CO2 Concentration, Global Temperature, Sea Level Rise")

# Show color bar
plt.colorbar(ax.collections[0], ax=ax, label="Arctic Ice Area (million km²)")

# Show plot
plt.show()

# %% [markdown]
# ###  Pair Plot for Multiple Variables

# %%
columns = ['Global Average Temperature (°C)', 'CO2 Concentration (ppm)', 'Sea Level Rise (mm)', 'Arctic Ice Area (million km²)']

# Create pairplot
sns.pairplot(aggregate_data_by_year[columns], height=2.5)
plt.suptitle("Pair Plot of Climate Variables", y=1.02)
plt.show()

# %% [markdown]
# ## 4. Multivariate Analysis
#
# Investigate relationships among three or more variables.

# %%
# TODO: Perform multivariate analysis
# Create advanced visualizations showing multiple variables
# Your code here


correlation_matrix = aggregate_data_by_year[columns].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Climate Variables")
plt.show()

# %% [markdown]
# ## 5. Conclusions and Insights
#
# Summarize your findings and discuss their implications.

# %% [markdown]
# # TODO: Write your conclusions here

# %%
Reports:
